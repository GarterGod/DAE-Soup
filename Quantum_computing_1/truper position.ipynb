# %%
# !pip install numpy

# !pip install qiskit
# Out:
# Requirement already satisfied: numpy in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.4.1)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\dsmol\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: qiskit in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (2.4.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (1.17.0)
# Requirement already satisfied: dill>=0.3 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (4.15.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\dsmol\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install qiskit
# Out:
# Requirement already satisfied: qiskit in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (2.4.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (1.17.0)
# Requirement already satisfied: dill>=0.3 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\dsmol\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from qiskit) (4.15.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\dsmol\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])
circuit.h(qreg_q[1])


circuit.draw('text')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
#       2 from numpy import pi
#       4 qreg_q = QuantumRegister(4, 'q')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\__init__.py:143
#     140 from qiskit.exceptions import QiskitError, MissingOptionalLibraryError
#     142 # The main qiskit operators
# --> 143 from qiskit.circuit import ClassicalRegister
#     144 from qiskit.circuit import QuantumRegister
#     145 from qiskit.circuit import AncillaRegister
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\circuit\__init__.py:1412
#    1410 from .quantumcircuitdata import CircuitInstruction
#    1411 from .equivalence import EquivalenceLibrary
# -> 1412 from . import library
#    1413 from .equivalence_library import StandardEquivalenceLibrary, SessionEquivalenceLibrary
#    1414 from .commutation_checker import CommutationChecker
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\circuit\library\__init__.py:923
#     911 from .boolean_logic import (
#     912     AND,
#     913     AndGate,
#    (...)    920     InnerProductGate,
#     921 )
#     922 from .basis_change import QFT, QFTGate
# --> 923 from .arithmetic import (
#     924     ModularAdderGate,
#     925     HalfAdderGate,
#     926     FullAdderGate,
#     927     MultiplierGate,
#     928     FunctionalPauliRotations,
#     929     LinearPauliRotations,
#     930     LinearPauliRotationsGate,
#     931     PiecewiseLinearPauliRotations,
#     932     PiecewiseLinearPauliRotationsGate,
#     933     PiecewisePolynomialPauliRotations,
#     934     PiecewisePolynomialPauliRotationsGate,
#     935     PolynomialPauliRotations,
#     936     PolynomialPauliRotationsGate,
#     937     IntegerComparator,
#     938     IntegerComparatorGate,
#     939     WeightedAdder,
#     940     WeightedSumGate,
#     941     QuadraticForm,
#     942     QuadraticFormGate,
#     943     LinearAmplitudeFunction,
#     944     LinearAmplitudeFunctionGate,
#     945     VBERippleCarryAdder,
#     946     CDKMRippleCarryAdder,
#     947     DraperQFTAdder,
#     948     PiecewiseChebyshev,
#     949     PiecewiseChebyshevGate,
#     950     HRSCumulativeMultiplier,
#     951     RGQFTMultiplier,
#     952     ExactReciprocal,
#     953     ExactReciprocalGate,
#     954 )
#     956 from .n_local import (
#     957     n_local,
#     958     NLocal,
#    (...)    972     QAOAAnsatz,
#     973 )
#     974 from .data_preparation import (
#     975     z_feature_map,
#     976     zz_feature_map,
#    (...)    982     Initialize,
#     983 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\circuit\library\arithmetic\__init__.py:16
#      13 """The arithmetic circuit library."""
#      15 from .functional_pauli_rotations import FunctionalPauliRotations
# ---> 16 from .integer_comparator import IntegerComparator, IntegerComparatorGate
#      17 from .linear_pauli_rotations import LinearPauliRotations, LinearPauliRotationsGate
#      18 from .piecewise_linear_pauli_rotations import (
#      19     PiecewiseLinearPauliRotations,
#      20     PiecewiseLinearPauliRotationsGate,
#      21 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\circuit\library\arithmetic\integer_comparator.py:20
#      18 from qiskit.circuit import QuantumRegister, AncillaRegister, Gate
#      19 from qiskit.circuit.exceptions import CircuitError
# ---> 20 from qiskit.synthesis.arithmetic.comparators import (
#      21     synth_integer_comparator_2s,
#      22     synth_integer_comparator_greedy,
#      23 )
#      24 from ..blueprintcircuit import BlueprintCircuit
#      27 class IntegerComparator(BlueprintCircuit):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\synthesis\__init__.py:227
#     225 from .qft import synth_qft_line, synth_qft_full
#     226 from .unitary.qsd import qs_decomposition
# --> 227 from .unitary import aqc
#     228 from .one_qubit import OneQubitEulerDecomposer
#     229 from .two_qubit.xx_decompose import XXDecomposer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\synthesis\unitary\aqc\__init__.py:175
#     173 from .aqc import AQC
#     174 from .cnot_structures import make_cnot_network
# --> 175 from .cnot_unit_circuit import CNOTUnitCircuit
#     176 from .cnot_unit_objective import CNOTUnitObjective, DefaultCNOTUnitObjective
#     177 from .fast_gradient.fast_gradient import FastCNOTUnitObjective
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1130, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])

circuit.draw('text')
